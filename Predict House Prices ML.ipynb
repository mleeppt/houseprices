# %%
import pandas as pd

fed_files = ["MORTGAGE30US.csv", "RRVRUSQ156N.csv", "CPIAUCSL.csv"]

dfs = [pd.read_csv(f, parse_dates=True, index_col=0) for f in fed_files]

dfs[0]
# Out:
#             MORTGAGE30US
# DATE
# 1971-04-02          7.33
# 1971-04-09          7.31
# 1971-04-16          7.31
# 1971-04-23          7.31
# 1971-04-30          7.29
# ...                  ...
# 2022-07-14          5.51
# 2022-07-21          5.54
# 2022-07-28          5.30
# 2022-08-04          4.99
# 2022-08-11          5.22
#
# [2681 rows x 1 columns]

# %%
dfs[1]
# Out:
#             RRVRUSQ156N
# DATE
# 1956-01-01          6.2
# 1956-04-01          5.9
# 1956-07-01          6.3
# 1956-10-01          5.8
# 1957-01-01          5.3
# ...                 ...
# 2021-04-01          6.2
# 2021-07-01          5.8
# 2021-10-01          5.6
# 2022-01-01          5.8
# 2022-04-01          5.6
#
# [266 rows x 1 columns]

# %%
fed_files = ["MORTGAGE30US.csv", "RRVRUSQ156N.csv", "CPIAUCSL.csv"]

#create a variable called name_length to store the length of the list
name_length = len(fed_files)

#print value of variable to the console
print(name_length)
# Out:
# 3

# %%
fed_files = ["MORTGAGE30US.csv", "RRVRUSQ156N.csv", "CPIAUCSL.csv"]
dfs[0] #MORTGAGE30US.csv
dfs[1] #RRVRUSQ156N.csv
dfs[2] #CPIAUCSL.csv not sure why this is listed as out of range have to use dfs[-1] for this possibly
# Out:
#             CPIAUCSL
# DATE
# 1947-01-01    21.480
# 1947-02-01    21.620
# 1947-03-01    22.000
# 1947-04-01    22.000
# 1947-05-01    21.950
# ...              ...
# 2022-03-01   287.708
# 2022-04-01   288.663
# 2022-05-01   291.474
# 2022-06-01   295.328
# 2022-07-01   295.271
#
# [907 rows x 1 columns]

# %%
import pandas as pd

fed_files = ["MORTGAGE30US.csv", "RRVRUSQ156N.csv", "CPIAUCSL.csv"]

dfs = [pd.read_csv(f, parse_dates=True, index_col=0) for f in fed_files]

dfs[0]
# Out:
#             MORTGAGE30US
# DATE
# 1971-04-02          7.33
# 1971-04-09          7.31
# 1971-04-16          7.31
# 1971-04-23          7.31
# 1971-04-30          7.29
# ...                  ...
# 2022-07-14          5.51
# 2022-07-21          5.54
# 2022-07-28          5.30
# 2022-08-04          4.99
# 2022-08-11          5.22
#
# [2681 rows x 1 columns]

# %%
import pandas as pd

fed_files = ["MORTGAGE30US.csv", "RRVRUSQ156N.csv", "CPIAUCSL.csv"]

dfs = [pd.read_csv(f, parse_dates=True, index_col=0) for f in fed_files]

dfs[0]
# Out:
#             MORTGAGE30US
# DATE
# 1971-04-02          7.33
# 1971-04-09          7.31
# 1971-04-16          7.31
# 1971-04-23          7.31
# 1971-04-30          7.29
# ...                  ...
# 2022-07-14          5.51
# 2022-07-21          5.54
# 2022-07-28          5.30
# 2022-08-04          4.99
# 2022-08-11          5.22
#
# [2681 rows x 1 columns]

# %%
fed_data = pd.concat(dfs, axis=1)

fed_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 1947-01-01           NaN          NaN     21.48
# 1947-02-01           NaN          NaN     21.62
# 1947-03-01           NaN          NaN     22.00
# 1947-04-01           NaN          NaN     22.00
# 1947-05-01           NaN          NaN     21.95
# ...                  ...          ...       ...
# 2022-07-14          5.51          NaN       NaN
# 2022-07-21          5.54          NaN       NaN
# 2022-07-28          5.30          NaN       NaN
# 2022-08-04          4.99          NaN       NaN
# 2022-08-11          5.22          NaN       NaN
#
# [3507 rows x 3 columns]

# %%
fed_data.tail(50) ##pulls last 50 rows
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 2021-11-01           NaN          NaN   278.524
# 2021-11-04          3.09          NaN       NaN
# 2021-11-10          2.98          NaN       NaN
# 2021-11-18          3.10          NaN       NaN
# 2021-11-24          3.10          NaN       NaN
# 2021-12-01           NaN          NaN   280.126
# 2021-12-02          3.11          NaN       NaN
# 2021-12-09          3.10          NaN       NaN
# 2021-12-16          3.12          NaN       NaN
# 2021-12-23          3.05          NaN       NaN
# 2021-12-30          3.11          NaN       NaN
# 2022-01-01           NaN          5.8   281.933
# 2022-01-06          3.22          NaN       NaN
# 2022-01-13          3.45          NaN       NaN
# 2022-01-20          3.56          NaN       NaN
# 2022-01-27          3.55          NaN       NaN
# 2022-02-01           NaN          NaN   284.182
# 2022-02-03          3.55          NaN       NaN
# 2022-02-10          3.69          NaN       NaN
# 2022-02-17          3.92          NaN       NaN
# 2022-02-24          3.89          NaN       NaN
# 2022-03-01           NaN          NaN   287.708
# 2022-03-03          3.76          NaN       NaN
# 2022-03-10          3.85          NaN       NaN
# 2022-03-17          4.16          NaN       NaN
# 2022-03-24          4.42          NaN       NaN
# 2022-03-31          4.67          NaN       NaN
# 2022-04-01           NaN          5.6   288.663
# 2022-04-07          4.72          NaN       NaN
# 2022-04-14          5.00          NaN       NaN
# 2022-04-21          5.11          NaN       NaN
# 2022-04-28          5.10          NaN       NaN
# 2022-05-01           NaN          NaN   291.474
# 2022-05-05          5.27          NaN       NaN
# 2022-05-12          5.30          NaN       NaN
# 2022-05-19          5.25          NaN       NaN
# 2022-05-26          5.10          NaN       NaN
# 2022-06-01           NaN          NaN   295.328
# 2022-06-02          5.09          NaN       NaN
# 2022-06-09          5.23          NaN       NaN
# 2022-06-16          5.78          NaN       NaN
# 2022-06-23          5.81          NaN       NaN
# 2022-06-30          5.70          NaN       NaN
# 2022-07-01           NaN          NaN   295.271
# 2022-07-07          5.30          NaN       NaN
# 2022-07-14          5.51          NaN       NaN
# 2022-07-21          5.54          NaN       NaN
# 2022-07-28          5.30          NaN       NaN
# 2022-08-04          4.99          NaN       NaN
# 2022-08-11          5.22          NaN       NaN

# %%
fed_data = fed_data.ffill()

fed_data.tail(50)
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 2021-11-01          3.14          5.6   278.524
# 2021-11-04          3.09          5.6   278.524
# 2021-11-10          2.98          5.6   278.524
# 2021-11-18          3.10          5.6   278.524
# 2021-11-24          3.10          5.6   278.524
# 2021-12-01          3.10          5.6   280.126
# 2021-12-02          3.11          5.6   280.126
# 2021-12-09          3.10          5.6   280.126
# 2021-12-16          3.12          5.6   280.126
# 2021-12-23          3.05          5.6   280.126
# 2021-12-30          3.11          5.6   280.126
# 2022-01-01          3.11          5.8   281.933
# 2022-01-06          3.22          5.8   281.933
# 2022-01-13          3.45          5.8   281.933
# 2022-01-20          3.56          5.8   281.933
# 2022-01-27          3.55          5.8   281.933
# 2022-02-01          3.55          5.8   284.182
# 2022-02-03          3.55          5.8   284.182
# 2022-02-10          3.69          5.8   284.182
# 2022-02-17          3.92          5.8   284.182
# 2022-02-24          3.89          5.8   284.182
# 2022-03-01          3.89          5.8   287.708
# 2022-03-03          3.76          5.8   287.708
# 2022-03-10          3.85          5.8   287.708
# 2022-03-17          4.16          5.8   287.708
# 2022-03-24          4.42          5.8   287.708
# 2022-03-31          4.67          5.8   287.708
# 2022-04-01          4.67          5.6   288.663
# 2022-04-07          4.72          5.6   288.663
# 2022-04-14          5.00          5.6   288.663
# 2022-04-21          5.11          5.6   288.663
# 2022-04-28          5.10          5.6   288.663
# 2022-05-01          5.10          5.6   291.474
# 2022-05-05          5.27          5.6   291.474
# 2022-05-12          5.30          5.6   291.474
# 2022-05-19          5.25          5.6   291.474
# 2022-05-26          5.10          5.6   291.474
# 2022-06-01          5.10          5.6   295.328
# 2022-06-02          5.09          5.6   295.328
# 2022-06-09          5.23          5.6   295.328
# 2022-06-16          5.78          5.6   295.328
# 2022-06-23          5.81          5.6   295.328
# 2022-06-30          5.70          5.6   295.328
# 2022-07-01          5.70          5.6   295.271
# 2022-07-07          5.30          5.6   295.271
# 2022-07-14          5.51          5.6   295.271
# 2022-07-21          5.54          5.6   295.271
# 2022-07-28          5.30          5.6   295.271
# 2022-08-04          4.99          5.6   295.271
# 2022-08-11          5.22          5.6   295.271

# %%
zillow_files = ["Metro_median_sale_price_uc_sfrcondo_week.csv", "Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_month.csv"]

dfs = [pd.read_csv(f) for f in zillow_files]

# %%
dfs[0]
# Out:
#     RegionID  SizeRank                          RegionName RegionType  \
# 0     102001         0                       United States    Country
# 1     394913         1                        New York, NY        Msa
# 2     753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3     394463         3                         Chicago, IL        Msa
# 4     394514         4               Dallas-Fort Worth, TX        Msa
# ..       ...       ...                                 ...        ...
# 79    394528        90                   Daytona Beach, FL        Msa
# 80    394531        91                      Des Moines, IA        Msa
# 81    395006       100                           Provo, UT        Msa
# 82    394549       104                          Durham, NC        Msa
# 83    394602       159                    Fort Collins, CO        Msa
#
#    StateName  2008-02-02  2008-02-09  2008-02-16  2008-02-23  2008-03-01  ...  \
# 0        NaN    190000.0    190000.0    193000.0    189900.0    194900.0  ...
# 1         NY    400000.0    418250.0    420000.0    420000.0    400000.0  ...
# 2         CA    497500.0    515000.0    520000.0    525000.0    498250.0  ...
# 3         IL    245000.0    245000.0    251000.0    255000.0    255000.0  ...
# 4         TX    144250.0    148900.0    139000.0    143700.0    145900.0  ...
# ..       ...         ...         ...         ...         ...         ...  ...
# 79        FL         NaN    170000.0    182400.0    170000.0    170000.0  ...
# 80        IA    138000.0    160000.0    150000.0    151750.0    154500.0  ...
# 81        UT         NaN    206000.0    215500.0    210000.0    210000.0  ...
# 82        NC    210000.0    170000.0    170500.0    197500.0    180000.0  ...
# 83        CO         NaN    255000.0    205000.0    229900.0    235000.0  ...
#
#     2022-05-07  2022-05-14  2022-05-21  2022-05-28  2022-06-04  2022-06-11  \
# 0     369900.0    370000.0    370000.0    375000.0    375000.0    370000.0
# 1     550000.0    555000.0    550000.0    575000.0    575000.0    578000.0
# 2     914000.0    925000.0    925000.0    951000.0    950000.0    920500.0
# 3     315000.0    310000.0    315500.0    315000.0    330000.0    324950.0
# 4     422000.0    430000.0    430000.0    425000.0    440000.0    425000.0
# ..         ...         ...         ...         ...         ...         ...
# 79    340500.0    345000.0    327700.0    345000.0    350000.0    343250.0
# 80    270000.0    285250.0    295000.0    273450.0    301000.0    290000.0
# 81    527000.0    540000.0    535000.0    552500.0    543750.0    571000.0
# 82    456000.0    450000.0    428500.0    480000.0    465000.0    440000.0
# 83    575000.0    585250.0    575000.0    550000.0    569900.0    560000.0
#
#     2022-06-18  2022-06-25  2022-07-02  2022-07-09
# 0     375000.0    370000.0    370000.0    362500.0
# 1     590000.0    582000.0    585000.0    595000.0
# 2     925000.0    900000.0    900500.0    906000.0
# 3     335000.0    325000.0    325000.0    315000.0
# 4     427750.0    426000.0    420000.0    420000.0
# ..         ...         ...         ...         ...
# 79    359900.0    352000.0    336000.0    342990.0
# 80    300900.0    281900.0    289250.0    280000.0
# 81    530300.0    569900.0    539950.0    572500.0
# 82    450250.0    416000.0    465000.0    435250.0
# 83    595000.0    550000.0    556058.0    595000.0
#
# [84 rows x 759 columns]

# %%
dfs[1]
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 0      102001         0                       United States    Country
# 1      394913         1                        New York, NY        Msa
# 2      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3      394463         3                         Chicago, IL        Msa
# 4      394514         4               Dallas-Fort Worth, TX        Msa
# ..        ...       ...                                 ...        ...
# 908    394767       929                          Lamesa, TX        Msa
# 909    753874       930                           Craig, CO        Msa
# 910    394968       931                           Pecos, TX        Msa
# 911    395188       932                          Vernon, TX        Msa
# 912    394743       933                       Ketchikan, AK        Msa
#
#     StateName     1/31/1996     2/29/1996     3/31/1996     4/30/1996  \
# 0         NaN  108641.26470  108472.72890  108532.28010  108739.07750
# 1          NY  188550.30690  186833.46050  186448.08910  186132.00310
# 2          CA  186683.04110  186015.16520  185723.79710  185700.15530
# 3          IL  147341.93160  147341.15290  146420.37940  147841.91880
# 4          TX  113283.51300  113199.11360  113519.42360  114048.06470
# ..        ...           ...           ...           ...           ...
# 908        TX           NaN           NaN           NaN           NaN
# 909        CO   66532.40104   66795.08306   67178.69152   67680.53239
# 910        TX           NaN           NaN           NaN           NaN
# 911        TX           NaN           NaN           NaN           NaN
# 912        AK           NaN           NaN           NaN           NaN
#
#         5/31/1996  ...    10/31/2021    11/30/2021    12/31/2021  \
# 0    108986.62160  ...  318648.55730  322227.27600  327377.25090
# 1    186023.97950  ...  573099.18370  575351.02070  577891.69820
# 2    185569.29820  ...  854076.99970  862487.34740  874894.41320
# 3    148371.38970  ...  288899.10370  290304.88790  291998.70220
# 4    114287.44430  ...  338187.52540  344409.90650  351186.03780
# ..            ...  ...           ...           ...           ...
# 908           NaN  ...   92899.03825   92999.75455   97296.41526
# 909   67149.04067  ...  244845.35490  245187.64360  253767.11930
# 910           NaN  ...  169404.97360  171295.73960  178176.87100
# 911           NaN  ...   80043.97477   80196.50729           NaN
# 912           NaN  ...  341065.61350  341843.73490           NaN
#
#         1/31/2022     2/28/2022     3/31/2022     4/30/2022     5/31/2022  \
# 0    332206.79010  338002.74770  344042.43310  350515.84180  354717.72290
# 1    582902.11720  588521.05690  598696.26840  607668.47980  615457.37980
# 2    888106.12400  902359.87150  931407.63880  950811.53300  955845.19000
# 3    294814.36820  298667.82410  304076.77950  308802.10560  314032.37830
# 4    359878.89360  370452.36960  376522.09040  391696.58540  399613.32410
# ..            ...           ...           ...           ...           ...
# 908   98217.63915  100010.33130  101084.70020  101376.96660  103321.69490
# 909  254926.31160  253700.14000  255387.31470  254937.50670  256166.40900
# 910  178929.21780  179113.93870  181811.01550  184752.02590  187573.84730
# 911   86966.99430   88535.64314   88556.49589   88921.71946   89261.93151
# 912  357590.41380  355276.56600  357039.62530  359121.85820  361530.06530
#
#         6/30/2022     7/31/2022
# 0    357473.32740  357107.27160
# 1    619722.31050  621307.89490
# 2    933648.29600  929753.42590
# 3    315084.42460  314178.55060
# 4    401254.77540  396903.77370
# ..            ...           ...
# 908  105794.45110  106244.14940
# 909  266655.03910  268370.63400
# 910  192967.34220  193366.79430
# 911   92129.40869   93197.60242
# 912  369073.05840  369920.03060
#
# [913 rows x 324 columns]

# %%
dfs = [pd.DataFrame(df.iloc[0,5:]) for df in dfs]

# %%
dfs[0]
# Out:
#                    0
# 2008-02-02  190000.0
# 2008-02-09  190000.0
# 2008-02-16  193000.0
# 2008-02-23  189900.0
# 2008-03-01  194900.0
# ...              ...
# 2022-06-11  370000.0
# 2022-06-18  375000.0
# 2022-06-25  370000.0
# 2022-07-02  370000.0
# 2022-07-09  362500.0
#
# [754 rows x 1 columns]

# %%
dfs[1]
# Out:
#                      0
# 1/31/1996  108641.2647
# 2/29/1996  108472.7289
# 3/31/1996  108532.2801
# 4/30/1996  108739.0775
# 5/31/1996  108986.6216
# ...                ...
# 3/31/2022  344042.4331
# 4/30/2022  350515.8418
# 5/31/2022  354717.7229
# 6/30/2022  357473.3274
# 7/31/2022  357107.2716
#
# [319 rows x 1 columns]

# %%
for df in dfs:
    df.index = pd.to_datetime(df.index)
    df["month"] = df.index.to_period("M")
dfs[1]
# Out:
#                       0    month
# 1996-01-31  108641.2647  1996-01
# 1996-02-29  108472.7289  1996-02
# 1996-03-31  108532.2801  1996-03
# 1996-04-30  108739.0775  1996-04
# 1996-05-31  108986.6216  1996-05
# ...                 ...      ...
# 2022-03-31  344042.4331  2022-03
# 2022-04-30  350515.8418  2022-04
# 2022-05-31  354717.7229  2022-05
# 2022-06-30  357473.3274  2022-06
# 2022-07-31  357107.2716  2022-07
#
# [319 rows x 2 columns]

# %%
price_data = dfs[0].merge(dfs[1], on="month")
price_data.index = dfs[0].index

# %%
price_data
# Out:
#                  0_x    month          0_y
# 2008-02-02  190000.0  2008-02  206885.8533
# 2008-02-09  190000.0  2008-02  206885.8533
# 2008-02-16  193000.0  2008-02  206885.8533
# 2008-02-23  189900.0  2008-02  206885.8533
# 2008-03-01  194900.0  2008-03   205459.522
# ...              ...      ...          ...
# 2022-06-11  370000.0  2022-06  357473.3274
# 2022-06-18  375000.0  2022-06  357473.3274
# 2022-06-25  370000.0  2022-06  357473.3274
# 2022-07-02  370000.0  2022-07  357107.2716
# 2022-07-09  362500.0  2022-07  357107.2716
#
# [754 rows x 3 columns]

# %%
print(price_data)
# Out:
#                  0_x    month          0_y
# 2008-02-02  190000.0  2008-02  206885.8533
# 2008-02-09  190000.0  2008-02  206885.8533
# 2008-02-16  193000.0  2008-02  206885.8533
# 2008-02-23  189900.0  2008-02  206885.8533
# 2008-03-01  194900.0  2008-03   205459.522
# ...              ...      ...          ...
# 2022-06-11  370000.0  2022-06  357473.3274
# 2022-06-18  375000.0  2022-06  357473.3274
# 2022-06-25  370000.0  2022-06  357473.3274
# 2022-07-02  370000.0  2022-07  357107.2716
# 2022-07-09  362500.0  2022-07  357107.2716
#
# [754 rows x 3 columns]

# %%
del price_data["month"]
price_data.columns = ["price", "value"]
price_data
# Out:
#                price        value
# 2008-02-02  190000.0  206885.8533
# 2008-02-09  190000.0  206885.8533
# 2008-02-16  193000.0  206885.8533
# 2008-02-23  189900.0  206885.8533
# 2008-03-01  194900.0   205459.522
# ...              ...          ...
# 2022-06-11  370000.0  357473.3274
# 2022-06-18  375000.0  357473.3274
# 2022-06-25  370000.0  357473.3274
# 2022-07-02  370000.0  357107.2716
# 2022-07-09  362500.0  357107.2716
#
# [754 rows x 2 columns]

# %%
fed_data = fed_data.dropna()
fed_data.tail(20)
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 2022-04-21          5.11          5.6   288.663
# 2022-04-28          5.10          5.6   288.663
# 2022-05-01          5.10          5.6   291.474
# 2022-05-05          5.27          5.6   291.474
# 2022-05-12          5.30          5.6   291.474
# 2022-05-19          5.25          5.6   291.474
# 2022-05-26          5.10          5.6   291.474
# 2022-06-01          5.10          5.6   295.328
# 2022-06-02          5.09          5.6   295.328
# 2022-06-09          5.23          5.6   295.328
# 2022-06-16          5.78          5.6   295.328
# 2022-06-23          5.81          5.6   295.328
# 2022-06-30          5.70          5.6   295.328
# 2022-07-01          5.70          5.6   295.271
# 2022-07-07          5.30          5.6   295.271
# 2022-07-14          5.51          5.6   295.271
# 2022-07-21          5.54          5.6   295.271
# 2022-07-28          5.30          5.6   295.271
# 2022-08-04          4.99          5.6   295.271
# 2022-08-11          5.22          5.6   295.271

# %%
from datetime import timedelta

fed_data.index = fed_data.index + timedelta(days=-12)

fed_data.tail(10)
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 2022-06-04          5.78          5.6   295.328
# 2022-06-11          5.81          5.6   295.328
# 2022-06-18          5.70          5.6   295.328
# 2022-06-19          5.70          5.6   295.271
# 2022-06-25          5.30          5.6   295.271
# 2022-07-02          5.51          5.6   295.271
# 2022-07-09          5.54          5.6   295.271
# 2022-07-16          5.30          5.6   295.271
# 2022-07-23          4.99          5.6   295.271
# 2022-07-30          5.22          5.6   295.271

# %%
print(price_data.dtypes)
# Out:
# price    object
# value    object
# dtype: object

# %%
price_data['price'] = pd.to_numeric(price_data['price'])
price_data['value'] = pd.to_numeric(price_data['value'])

# %%
print(price_data.dtypes)
# Out:
# price    float64
# value    float64
# dtype: object

# %%
print(fed_data.dtypes)
# Out:
# MORTGAGE30US    float64
# RRVRUSQ156N     float64
# CPIAUCSL        float64
# dtype: object

# %%
price_data = fed_data.merge(price_data, left_index=True, right_index=True)

# %%
price_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL     price        value
# 2008-02-02          5.72         10.1   212.687  190000.0  206885.8533
# 2008-02-09          6.04         10.1   212.687  190000.0  206885.8533
# 2008-02-16          6.24         10.1   212.687  193000.0  206885.8533
# 2008-02-23          6.03         10.1   213.448  189900.0  206885.8533
# 2008-03-01          6.13         10.1   213.448  194900.0  205459.5220
# ...                  ...          ...       ...       ...          ...
# 2022-06-11          5.81          5.6   295.328  370000.0  357473.3274
# 2022-06-18          5.70          5.6   295.328  375000.0  357473.3274
# 2022-06-25          5.30          5.6   295.271  370000.0  357473.3274
# 2022-07-02          5.51          5.6   295.271  370000.0  357107.2716
# 2022-07-09          5.54          5.6   295.271  362500.0  357107.2716
#
# [735 rows x 5 columns]

# %%
price_data.columns = ["interest","vacancy", "cpi", "price", "value"]
price_data
# Out:
#             interest  vacancy      cpi     price        value
# 2008-02-02      5.72     10.1  212.687  190000.0  206885.8533
# 2008-02-09      6.04     10.1  212.687  190000.0  206885.8533
# 2008-02-16      6.24     10.1  212.687  193000.0  206885.8533
# 2008-02-23      6.03     10.1  213.448  189900.0  206885.8533
# 2008-03-01      6.13     10.1  213.448  194900.0  205459.5220
# ...              ...      ...      ...       ...          ...
# 2022-06-11      5.81      5.6  295.328  370000.0  357473.3274
# 2022-06-18      5.70      5.6  295.328  375000.0  357473.3274
# 2022-06-25      5.30      5.6  295.271  370000.0  357473.3274
# 2022-07-02      5.51      5.6  295.271  370000.0  357107.2716
# 2022-07-09      5.54      5.6  295.271  362500.0  357107.2716
#
# [735 rows x 5 columns]

# %%
price_data.plot.line(y="price", use_index=True)
# Out:
# <Axes: >

# %%
price_data["adj_price"] = price_data["price"] / price_data["cpi"] * 100
price_data.plot.line(y="adj_price", use_index=True)
# Out:
# <Axes: >

# %%
price_data["adj_value"] = price_data["value"] / price_data["cpi"] * 100

# %%
price_data["next_quarter"] = price_data["adj_price"].shift(-13)
price_data
# Out:
#             interest  vacancy      cpi     price        value      adj_price  \
# 2008-02-02      5.72     10.1  212.687  190000.0  206885.8533   89333.151533
# 2008-02-09      6.04     10.1  212.687  190000.0  206885.8533   89333.151533
# 2008-02-16      6.24     10.1  212.687  193000.0  206885.8533   90743.674978
# 2008-02-23      6.03     10.1  213.448  189900.0  206885.8533   88967.804805
# 2008-03-01      6.13     10.1  213.448  194900.0  205459.5220   91310.295716
# ...              ...      ...      ...       ...          ...            ...
# 2022-06-11      5.81      5.6  295.328  370000.0  357473.3274  125284.429516
# 2022-06-18      5.70      5.6  295.328  375000.0  357473.3274  126977.462347
# 2022-06-25      5.30      5.6  295.271  370000.0  357473.3274  125308.614798
# 2022-07-02      5.51      5.6  295.271  370000.0  357107.2716  125308.614798
# 2022-07-09      5.54      5.6  295.271  362500.0  357107.2716  122768.575309
#
#                 adj_value  next_quarter
# 2008-02-02   97272.448857  90610.014498
# 2008-02-09   97272.448857  90563.547824
# 2008-02-16   97272.448857  91014.739229
# 2008-02-23   96925.646200  89670.426693
# 2008-03-01   96257.412578  91969.668403
# ...                   ...           ...
# 2022-06-11  121042.815920           NaN
# 2022-06-18  121042.815920           NaN
# 2022-06-25  121066.182388           NaN
# 2022-07-02  120942.209563           NaN
# 2022-07-09  120942.209563           NaN
#
# [735 rows x 8 columns]

# %%
price_data.dropna(inplace=True)
price_data
# Out:
#             interest  vacancy      cpi     price        value      adj_price  \
# 2008-02-02      5.72     10.1  212.687  190000.0  206885.8533   89333.151533
# 2008-02-09      6.04     10.1  212.687  190000.0  206885.8533   89333.151533
# 2008-02-16      6.24     10.1  212.687  193000.0  206885.8533   90743.674978
# 2008-02-23      6.03     10.1  213.448  189900.0  206885.8533   88967.804805
# 2008-03-01      6.13     10.1  213.448  194900.0  205459.5220   91310.295716
# ...              ...      ...      ...       ...          ...            ...
# 2022-03-12      4.42      5.8  287.708  350000.0  344042.4331  121651.118495
# 2022-03-19      4.67      5.8  287.708  350000.0  344042.4331  121651.118495
# 2022-03-26      4.72      5.6  288.663  355000.0  344042.4331  122980.776892
# 2022-04-02      5.00      5.6  288.663  360000.0  350515.8418  124712.900510
# 2022-04-09      5.11      5.6  288.663  365000.0  350515.8418  126445.024128
#
#                 adj_value   next_quarter
# 2008-02-02   97272.448857   90610.014498
# 2008-02-09   97272.448857   90563.547824
# 2008-02-16   97272.448857   91014.739229
# 2008-02-23   96925.646200   89670.426693
# 2008-03-01   96257.412578   91969.668403
# ...                   ...            ...
# 2022-03-12  119580.419418  125284.429516
# 2022-03-19  119580.419418  126977.462347
# 2022-03-26  119184.804807  125308.614798
# 2022-04-02  121427.353627  125308.614798
# 2022-04-09  121427.353627  122768.575309
#
# [722 rows x 8 columns]

# %%
price_data["change"] = (price_data["next_quarter"] > price_data["adj_price"]).astype(int)
price_data
# Out:
#             interest  vacancy      cpi     price        value      adj_price  \
# 2008-02-02      5.72     10.1  212.687  190000.0  206885.8533   89333.151533
# 2008-02-09      6.04     10.1  212.687  190000.0  206885.8533   89333.151533
# 2008-02-16      6.24     10.1  212.687  193000.0  206885.8533   90743.674978
# 2008-02-23      6.03     10.1  213.448  189900.0  206885.8533   88967.804805
# 2008-03-01      6.13     10.1  213.448  194900.0  205459.5220   91310.295716
# ...              ...      ...      ...       ...          ...            ...
# 2022-03-12      4.42      5.8  287.708  350000.0  344042.4331  121651.118495
# 2022-03-19      4.67      5.8  287.708  350000.0  344042.4331  121651.118495
# 2022-03-26      4.72      5.6  288.663  355000.0  344042.4331  122980.776892
# 2022-04-02      5.00      5.6  288.663  360000.0  350515.8418  124712.900510
# 2022-04-09      5.11      5.6  288.663  365000.0  350515.8418  126445.024128
#
#                 adj_value   next_quarter  change
# 2008-02-02   97272.448857   90610.014498       1
# 2008-02-09   97272.448857   90563.547824       1
# 2008-02-16   97272.448857   91014.739229       1
# 2008-02-23   96925.646200   89670.426693       1
# 2008-03-01   96257.412578   91969.668403       1
# ...                   ...            ...     ...
# 2022-03-12  119580.419418  125284.429516       1
# 2022-03-19  119580.419418  126977.462347       1
# 2022-03-26  119184.804807  125308.614798       1
# 2022-04-02  121427.353627  125308.614798       1
# 2022-04-09  121427.353627  122768.575309       0
#
# [722 rows x 9 columns]

# %%
price_data["change"].value_counts()
# Out:
# change
# 1    383
# 0    339
# Name: count, dtype: int64

# %%
predictors = ["interest", "vacancy", "adj_price", "adj_value"]
target = "change"

# %%
## import sys
## !{sys.executable} -m pip install scikit-learn

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import numpy as np

# %%
START = 260
STEP = 52

def predict(train, test, predictors, target): 
    rf = RandomForestClassifier(min_samples_split=10, random_state=1)
    rf.fit(train[predictors], train[target])
    preds = rf.predict(test[predictors])
    return preds

def backtest(data, predictors, target): 
    all_preds = []
    for i in range(START, data.shape[0], STEP):
        train = price_data.iloc[:i]
        test = price_data.iloc[i:(i+STEP)]
        all_preds.append(predict(train, test, predictors, target))

    preds = np.concatenate(all_preds)
    return preds, accuracy_score(data.iloc[START:][target], preds)

# %%
preds, accuracy = backtest(price_data, predictors, target)

# %%
accuracy
# Out:
# 0.6168831168831169
